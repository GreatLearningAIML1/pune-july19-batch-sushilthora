# %% [markdown]
# ### Build a DNN using Keras with `RELU` and `ADAM`

# %% [markdown]
# #### Load tensorflow

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import numpy as np

# %%
tf.__version__
# Out:
# '2.1.0-rc1'

# %% [markdown]
# #### Collect Fashion mnist data from tf.keras.datasets

# %%
(trainX, trainY),(testX, testY) = tf.keras.datasets.mnist.load_data()

# %%
trainX.shape #Image size 28*28
# Out:
# (60000, 28, 28)

# %%
testX.shape
# Out:
# (10000, 28, 28)

# %% [markdown]
# #### Change train and test labels into one-hot vectors

# %%
trainY = tf.keras.utils.to_categorical(trainY, num_classes=10)
testY = tf.keras.utils.to_categorical(testY, num_classes=10)

# %% [markdown]
# #### Build the Graph

# %% [markdown]
# #### Initialize model, reshape & normalize data

# %%
#Initialize model, reshape & normalize data
tf.keras.backend.clear_session()
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Reshape((784,),input_shape=(28,28,)))
model.add(tf.keras.layers.BatchNormalization())

# %% [markdown]
# #### Add two fully connected layers with 200 and 100 neurons respectively with `relu` activations. Add a dropout layer with `p=0.25`

# %%
#Hidden layers
model.add(tf.keras.layers.Dense(200, activation='relu', name='Layer_1'))
model.add(tf.keras.layers.Dense(100, activation='relu', name='Layer_2'))
#Dropout layer
model.add(tf.keras.layers.Dropout(0.25))

# %% [markdown]
# ### Add the output layer with a fully connected layer with 10 neurons with `softmax` activation. Use `categorical_crossentropy` loss and `adam` optimizer and train the network. And, report the final validation.

# %%
#Output layer
model.add(tf.keras.layers.Dense(10, activation='softmax', name='Output'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 784)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 784)               3136
# _________________________________________________________________
# Layer_1 (Dense)              (None, 200)               157000
# _________________________________________________________________
# Layer_2 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# Output (Dense)               (None, 10)                1010
# =================================================================
# Total params: 181,246
# Trainable params: 179,678
# Non-trainable params: 1,568
# _________________________________________________________________

# %%
#Train the model
model.fit(trainX,trainY,
          validation_data=(testX,testY),
          epochs=25,
          batch_size=32)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/25
# 60000/60000 [==============================] - 9s 157us/sample - loss: 0.2651 - accuracy: 0.9186 - val_loss: 0.3469 - val_accuracy: 0.9575
# Epoch 2/25
# 60000/60000 [==============================] - 9s 142us/sample - loss: 0.1324 - accuracy: 0.9600 - val_loss: 0.2692 - val_accuracy: 0.9681
# Epoch 3/25
# 60000/60000 [==============================] - 9s 144us/sample - loss: 0.1002 - accuracy: 0.9692 - val_loss: 0.2236 - val_accuracy: 0.9707
# Epoch 4/25
# 60000/60000 [==============================] - 9s 142us/sample - loss: 0.0806 - accuracy: 0.9748 - val_loss: 0.3990 - val_accuracy: 0.9693
# Epoch 5/25
# 60000/60000 [==============================] - 9s 143us/sample - loss: 0.0700 - accuracy: 0.9779 - val_loss: 0.4830 - val_accuracy: 0.9695
# Epoch 6/25
# 60000/60000 [==============================] - 9s 143us/sample - loss: 0.0598 - accuracy: 0.9806 - val_loss: 0.4634 - val_accuracy: 0.9704
# Epoch 7/25
# 60000/60000 [==============================] - 9s 146us/sample - loss: 0.0518 - accuracy: 0.9834 - val_loss: 0.6289 - val_accuracy: 0.9696
# Epoch 8/25
# 60000/60000 [==============================] - 9s 146us/sample - loss: 0.0513 - accuracy: 0.9837 - val_loss: 0.2418 - val_accuracy: 0.9737
# Epoch 9/25
# 60000/60000 [==============================] - 8s 139us/sample - loss: 0.0472 - accuracy: 0.9853 - val_loss: 0.2909 - val_accuracy: 0.9743
# Epoch 10/25
# 60000/60000 [==============================] - 9s 143us/sample - loss: 0.0409 - accuracy: 0.9873 - val_loss: 0.3269 - val_accuracy: 0.9708
# Epoch 11/25
# 60000/60000 [==============================] - 9s 145us/sample - loss: 0.0422 - accuracy: 0.9869 - val_loss: 0.3600 - val_accuracy: 0.9729
# Epoch 12/25
# 60000/60000 [==============================] - 9s 144us/sample - loss: 0.0382 - accuracy: 0.9879 - val_loss: 0.4760 - val_accuracy: 0.9752
# Epoch 13/25
# 60000/60000 [==============================] - 8s 141us/sample - loss: 0.0361 - accuracy: 0.9885 - val_loss: 0.3498 - val_accuracy: 0.9723
# Epoch 14/25
# 60000/60000 [==============================] - 9s 142us/sample - loss: 0.0354 - accuracy: 0.9888 - val_loss: 0.4129 - val_accuracy: 0.9735
# Epoch 15/25
# 60000/60000 [==============================] - 9s 157us/sample - loss: 0.0334 - accuracy: 0.9898 - val_loss: 0.3248 - val_accuracy: 0.9735
# Epoch 16/25
# 60000/60000 [==============================] - 11s 177us/sample - loss: 0.0304 - accuracy: 0.9902 - val_loss: 0.3556 - val_accuracy: 0.9712
# Epoch 17/25
# 60000/60000 [==============================] - 10s 174us/sample - loss: 0.0314 - accuracy: 0.9902 - val_loss: 0.5094 - val_accuracy: 0.9708
# Epoch 18/25
# 60000/60000 [==============================] - 10s 175us/sample - loss: 0.0306 - accuracy: 0.9905 - val_loss: 0.3489 - val_accuracy: 0.9743
# Epoch 19/25
# 60000/60000 [==============================] - 10s 173us/sample - loss: 0.0325 - accuracy: 0.9900 - val_loss: 0.3055 - val_accuracy: 0.9710
# Epoch 20/25
# 60000/60000 [==============================] - 10s 173us/sample - loss: 0.0268 - accuracy: 0.9915 - val_loss: 0.3575 - val_accuracy: 0.9732
# Epoch 21/25
# 60000/60000 [==============================] - 10s 174us/sample - loss: 0.0280 - accuracy: 0.9914 - val_loss: 0.3472 - val_accuracy: 0.9725
# Epoch 22/25
# 60000/60000 [==============================] - 11s 176us/sample - loss: 0.0281 - accuracy: 0.9914 - val_loss: 0.2890 - val_accuracy: 0.9742
# Epoch 23/25
# 60000/60000 [==============================] - 11s 178us/sample - loss: 0.0259 - accuracy: 0.9919 - val_loss: 0.3691 - val_accuracy: 0.9742
# Epoch 24/25
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.0270 - accuracy: 0.9920 - val_loss: 0.4958 - val_accuracy: 0.9714
# Epoch 25/25
# 60000/60000 [==============================] - 11s 178us/sample - loss: 0.0239 - accuracy: 0.9927 - val_loss: 0.3594 - val_accuracy: 0.9731
